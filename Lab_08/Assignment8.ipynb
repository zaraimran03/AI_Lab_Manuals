# %%
# -------------------------------
# LAB 8: LSTM Next Word Prediction
# -------------------------------

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# -------------------------------
# 1) Text Dataset (FAQs)
# -------------------------------
faqs = """About the Program
What is the course fee for  Data Science Mentorship Program (DSMP 2023)
The course follows a monthly subscription model where you have to make monthly payments of Rs 799/month.
What is the total duration of the course?
... (use full text from your description) ...
Discussion on Job hunting strategies
"""

# -------------------------------
# 2) Tokenize Text
# -------------------------------
tokenizer = Tokenizer()
tokenizer.fit_on_texts([faqs])

# Create input sequences for LSTM
input_sequences = []
for sentence in faqs.split('\n'):
    tokenized_sentence = tokenizer.texts_to_sequences([sentence])[0]
    for i in range(1, len(tokenized_sentence)):
        input_sequences.append(tokenized_sentence[:i+1])

# Pad sequences
max_len = max([len(x) for x in input_sequences])
padded_input_sequences = pad_sequences(input_sequences, maxlen=max_len, padding='pre')

# Split X and y
X = padded_input_sequences[:, :-1]
y = padded_input_sequences[:, -1]

# One-hot encode y
y = tf.keras.utils.to_categorical(y, num_classes=len(tokenizer.word_index)+1)

# Vocabulary size
vocab_size = len(tokenizer.word_index) + 1
print("Vocabulary size:", vocab_size)

# -------------------------------
# 3) Build LSTM Model
# -------------------------------
model = Sequential()
model.add(Embedding(vocab_size, 100, input_length=max_len-1))
model.add(LSTM(150, return_sequences=True))
model.add(LSTM(150))
model.add(Dense(vocab_size, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.build(input_shape=(None, max_len-1))
model.summary()

# -------------------------------
# 4) Train LSTM Model
# -------------------------------
history = model.fit(X, y, epochs=100, verbose=1)

# -------------------------------
# 5) Function: Predict Next Word (1 word)
# -------------------------------
def predict_next_word(model, tokenizer, text_seq, max_len=max_len):
    tokenized = tokenizer.texts_to_sequences([text_seq])[0]
    padded = pad_sequences([tokenized], maxlen=max_len-1, padding='pre')
    predicted_index = np.argmax(model.predict(padded, verbose=0))
    for word, index in tokenizer.word_index.items():
        if index == predicted_index:
            return word

# -------------------------------
# 6) Example: Predict 1 Next Word
# -------------------------------
seed_text = "what is the fee"
next_word = predict_next_word(model, tokenizer, seed_text)
print(f"Next word prediction: '{next_word}'")

# -------------------------------
# 7) Generate 5 Words Sequentially
# -------------------------------
def generate_words(model, tokenizer, seed_text, n_words=5, max_len=max_len):
    text = seed_text
    for _ in range(n_words):
        word = predict_next_word(model, tokenizer, text, max_len)
        text += " " + word
    return text

generated_text = generate_words(model, tokenizer, seed_text, n_words=5)
print(f"\nGenerated sequence (5 words): {generated_text}")
# Out:
# Vocabulary size: 42
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 17, 100)        │         4,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 17, 150)        │       150,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 150)            │       180,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 42)             │         6,342 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 341,742 (1.30 MB)
#  Trainable params: 341,742 (1.30 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - accuracy: 0.0000e+00 - loss: 3.7393
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.1141 - loss: 3.7227
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.0892 - loss: 3.7024
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0892 - loss: 3.6655
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1141 - loss: 3.5859
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1037 - loss: 3.5456
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.0996 - loss: 3.5140
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.1037 - loss: 3.4553
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1141 - loss: 3.4394
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.0788 - loss: 3.4382
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0747 - loss: 3.3747
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1141 - loss: 3.3038
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.0933 - loss: 3.2911
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.0996 - loss: 3.1900
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.1141 - loss: 3.1363
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.1495 - loss: 3.0706
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.1141 - loss: 3.0202
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.1535 - loss: 2.9307
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.1680 - loss: 2.8624
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.1535 - loss: 2.8083
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.1680 - loss: 2.7734
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.2219 - loss: 2.7197
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.2532 - loss: 2.6222
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.2428 - loss: 2.5562
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.2572 - loss: 2.5241
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.1970 - loss: 2.4950
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.2428 - loss: 2.4172
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.3111 - loss: 2.4011
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.2926 - loss: 2.3363
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.2781 - loss: 2.2541
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.3030 - loss: 2.2156
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.3320 - loss: 2.1831
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.3361 - loss: 2.1597
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4814 - loss: 2.0716
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4814 - loss: 2.0136
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.4357 - loss: 2.0114
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step - accuracy: 0.5104 - loss: 1.9005
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.5249 - loss: 1.8878
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.4855 - loss: 1.8875
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.4647 - loss: 1.8693
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.5249 - loss: 1.7532
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4959 - loss: 1.7275
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.4855 - loss: 1.7497
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5602 - loss: 1.6572
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.5851 - loss: 1.5963
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.5747 - loss: 1.6255
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.6495 - loss: 1.5337
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.6431 - loss: 1.5710
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.5933 - loss: 1.5121
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.6431 - loss: 1.4642
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6680 - loss: 1.4836
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.6889 - loss: 1.4243
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.6993 - loss: 1.3953
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.6744 - loss: 1.3745
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.6929 - loss: 1.3391
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7034 - loss: 1.2805
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.7283 - loss: 1.2554
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6970 - loss: 1.2738
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.7532 - loss: 1.2068
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7636 - loss: 1.1504
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.8030 - loss: 1.1650
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8030 - loss: 1.1334
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7781 - loss: 1.0867
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8279 - loss: 1.0370
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8465 - loss: 1.0964
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8071 - loss: 1.0524
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.7613 - loss: 1.0486
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7572 - loss: 1.0152
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8175 - loss: 0.9727
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.8320 - loss: 0.9613
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.8111 - loss: 0.9411
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8465 - loss: 0.9458
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8714 - loss: 0.8684
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.8922 - loss: 0.8409
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8465 - loss: 0.8904
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - accuracy: 0.8424 - loss: 0.8104
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.8714 - loss: 0.7832
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8818 - loss: 0.7903
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.8714 - loss: 0.7581
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.8818 - loss: 0.7790
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8610 - loss: 0.7443
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8755 - loss: 0.7470
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.8714 - loss: 0.7042
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.8714 - loss: 0.7110
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.8963 - loss: 0.7055
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.8465 - loss: 0.6812
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8465 - loss: 0.6685
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.8465 - loss: 0.6837
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.8963 - loss: 0.6351
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.9316 - loss: 0.6133
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.9212 - loss: 0.6272
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.9253 - loss: 0.6157
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.9565 - loss: 0.5614
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.9710 - loss: 0.5729
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.9461 - loss: 0.5810
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.9502 - loss: 0.5834
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9004 - loss: 0.6549
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9461 - loss: 0.5504
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - accuracy: 0.9357 - loss: 0.5833
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9253 - loss: 0.5826
# Next word prediction: 'fee'
#
# Generated sequence (5 words): what is the fee fee for data data science
